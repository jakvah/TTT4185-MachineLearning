# %% [markdown]
# # TTT4185 Machine learning for Speech technology
#
# ## Computer assigment 3b:  Regression analysis
#
# Regression analysis is used to estimate/measure the relationship between an _independent_ variable, say $x$, and a _dependent_ variable, say $y$. One of the simplest regression problems is
# \begin{equation}
# y = ax + b
# \end{equation}
# where $a$ and $b$ are constants. In practice our observations will be contaminated by noise, so we have
# \begin{equation}
# y = ax + b + n,
# \end{equation}
# where $n$ is noise, eg. measurement errors. This particular problem is called _linear regression_.
#
# We will have a look at _non-linear regression_, using deep neural networks. Here we are looking at general regression problems in the form
# \begin{equation}
# y = f(x) + n.
# \end{equation}
#
# We generate our data according to the function $f(x) = x^2 + \cos(20x) \text{ sign}(x)$, obtaining a set of observations $\{(x_i,y_i)\}$.
#
# Then we assume we do not know the underlying function and we try to recover and approximation of $f$ only using the observations $\{(x_i,y_i)\}$.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf
from tensorflow import keras

# %%
# Define function
def f(x):
    return x**2 + np.cos(20*x)*np.sign(x)

# Setup some simulation parameters
# Number of observations
N = 5000

# Plot a "clean" version of the relationship between x and y
plt.figure(figsize=(10, 8))
x = np.linspace(-2,2,N)
plt.plot(x,f(x))
plt.show()

# %%
# Create a noise version of the observations
y = f(x) + np.random.randn(len(x))
plt.figure(figsize=(10, 8))
plt.plot(x,y)
plt.show()

# %% [markdown]
# One way to perform regression is to assume that the data is generated using a set of functions from a cerain family, for example polynomials of order $p$,
# \begin{equation}
# \hat f(x) = a_0 + a_1 x + a_2 x^2 \ldots a_p x^p.
# \end{equation}
# Then regression corresponds to fitting the parameters in the model. Let us see how this works out before using our neural networks.

# %%
# Give a set of polynomial orders to try
P = [1, 2, 5, 10, 20]

# Define estimator function. Arguments are inout variable, observation and polynomial order
# Returns a set of polynomial coefficients
def reg_estimator(x,y,p):
    # Use simple ls approach
    N = len(x)
    H = np.zeros((N,p+1))
    for col in range(p+1):
        H[:,col] = x**col
    iHtH = np.linalg.inv(np.dot(H.T,H))
    theta = np.dot(np.dot(iHtH,H.T),y)
    return theta

# Computes fx) = c_0 + c_1x + c_2 x^2 ... c_p x^p
def poly(x, C):
    # compute p(x) for coeffs in c
    y = 0*x
    for p, c in enumerate(C):
        y += c*x**p        
    return y

plt.figure(figsize=(10,8))
plt.plot(x,f(x),label="Truth")
for p in P:
    C = reg_estimator(x,y,p)
    plt.plot(x,poly(x,C),label="Poly order " + str(p))
plt.legend()
plt.show()

# %% [markdown]
# ## Problem 1
# Play with different $p$ to see how close you can get to the true function.
#
# Note: Very high $p$ will give numerical problems.

# %%
# Give a set of polynomial orders to try
P = [1,21,22,23,24,25]

# Define estimator function. Arguments are inout variable, observation and polynomial order
# Returns a set of polynomial coefficients
def reg_estimator(x,y,p):
    # Use simple ls approach
    N = len(x)
    H = np.zeros((N,p+1))
    for col in range(p+1):
        H[:,col] = x**col
    iHtH = np.linalg.inv(np.dot(H.T,H))
    theta = np.dot(np.dot(iHtH,H.T),y)
    return theta

# Computes fx) = c_0 + c_1x + c_2 x^2 ... c_p x^p
def poly(x, C):
    # compute p(x) for coeffs in c
    y = 0*x
    for p, c in enumerate(C):
        y += c*x**p        
    return y

plt.figure(figsize=(10,8))
plt.plot(x,f(x),label="Truth")
for p in P:
    C = reg_estimator(x,y,p)
    plt.plot(x,poly(x,C),label="Poly order " + str(p))
plt.legend()
plt.show()

# %% [markdown]
# Seems like $p=23$ yields the best approximation. For very large $p$ (in the range of 50-100), the model explodes in the x-axis range (-0.5,1.5).

# %% [markdown]
# In what follows we will use a deep neural network to approximate $f$. We set this up below

# %%
# Ceate a model with a single hidden layer. Note that input and output has
# dimension one
M = 512
model = keras.Sequential([
    keras.layers.Dense(M, activation=tf.nn.relu, input_dim=1),
    keras.layers.Dense(1)
])

model.summary()
# Train the model
model.compile(loss='mean_squared_error',
              optimizer="adam",
              metrics=['accuracy'])
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_14 (Dense)             (None, 512)               1024
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 1,537
# Trainable params: 1,537
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# We train the network by using $x$ as an input and the squared error between the network output $\hat y$ and the observed value $y$ as a loss
# \begin{equation}
#  L = \frac{1}{N} \sum_n (\hat y - y)^2
# \end{equation}
#
# We first try our network on clean data to check if it works.

# %%
# train the model
history = model.fit(x, f(x), epochs=1000, batch_size=128, verbose=False)

# %% [markdown]
# Using the variable `history`, plot the evolution of the loss during training.

# %%
# Compute \hat y from the network and compare this to the true f(x)
z = model.predict(x)
plt.figure(figsize=(10,8))
plt.plot(x,f(x),label="Truth")
plt.plot(x,z,label="DNN")
plt.legend()
plt.show()

# %% [markdown]
# ## Problem 2
# Try increasing the number of nodes in the network to see if the results can be improved.

# %%
# Ceate a model with a single hidden layer. Note that input and output has
# dimension one
M_list = [10000]
for M in M_list:
    print("Using M = ",M)
    model = keras.Sequential([
        keras.layers.Dense(M, activation=tf.nn.relu, input_dim=1),
        keras.layers.Dense(1)
    ])

    model.summary()
    # Train the model
    model.compile(loss='mean_squared_error',
                optimizer="adam",
                metrics=['accuracy'])

    # train the model
    history = model.fit(x, f(x), epochs=1000, batch_size=128, verbose=False)

    # Compute \hat y from the network and compare this to the true f(x)
    z = model.predict(x)
    plt.figure(figsize=(10,8))
    plt.plot(x,f(x),label="Truth")
    plt.plot(x,z,label="DNN")
    title_string = "Using M = " + str(M)
    plt.title(title_string)
    plt.legend()
    plt.show()
# Out:
# Using M =  512
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_23 (Dense)             (None, 512)               1024
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 1,537
# Trainable params: 1,537
# Non-trainable params: 0
# _________________________________________________________________
# Using M =  1024
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_25 (Dense)             (None, 1024)              2048
# _________________________________________________________________
# dense_26 (Dense)             (None, 1)                 1025
# =================================================================
# Total params: 3,073
# Trainable params: 3,073
# Non-trainable params: 0
# _________________________________________________________________
# Using M =  2048
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_27 (Dense)             (None, 2048)              4096
# _________________________________________________________________
# dense_28 (Dense)             (None, 1)                 2049
# =================================================================
# Total params: 6,145
# Trainable params: 6,145
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Next we will use a deep network with more than one hidden layer.

# %%
# Create a model with multiple hidden layers. Note that input and output has
# dimension one
M = 16
model = keras.Sequential([
    keras.layers.Dense(M, activation=tf.nn.relu, input_dim=1),
    keras.layers.Dense(M, activation=tf.nn.relu),
    keras.layers.Dense(M, activation=tf.nn.relu),
    keras.layers.Dense(M, activation=tf.nn.relu),
    keras.layers.Dense(1)
])
model.summary()

# Train the model
model.compile(loss='mean_squared_error',
              optimizer="adam",
              metrics=['accuracy'])

history = model.fit(x, f(x), epochs=1000, batch_size=128, verbose=False)
# Out:
# =================] - 0s 2ms/step - loss: 0.1994 - accuracy: 0.0000e+00
# Epoch 813/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1975 - accuracy: 0.0000e+00
# Epoch 814/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1972 - accuracy: 0.0000e+00
# Epoch 815/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1996 - accuracy: 0.0000e+00
# Epoch 816/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1960 - accuracy: 0.0000e+00
# Epoch 817/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1982 - accuracy: 0.0000e+00
# Epoch 818/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1995 - accuracy: 0.0000e+00
# Epoch 819/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2017 - accuracy: 0.0000e+00
# Epoch 820/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2031 - accuracy: 0.0000e+00
# Epoch 821/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1980 - accuracy: 0.0000e+00
# Epoch 822/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2005 - accuracy: 0.0000e+00
# Epoch 823/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2008 - accuracy: 0.0000e+00
# Epoch 824/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2031 - accuracy: 0.0000e+00
# Epoch 825/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2016 - accuracy: 0.0000e+00
# Epoch 826/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2062 - accuracy: 0.0000e+00
# Epoch 827/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1976 - accuracy: 0.0000e+00
# Epoch 828/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1982 - accuracy: 0.0000e+00
# Epoch 829/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1964 - accuracy: 0.0000e+00
# Epoch 830/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1976 - accuracy: 0.0000e+00
# Epoch 831/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2011 - accuracy: 0.0000e+00
# Epoch 832/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2081 - accuracy: 0.0000e+00
# Epoch 833/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2011 - accuracy: 0.0000e+00
# Epoch 834/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1966 - accuracy: 0.0000e+00
# Epoch 835/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2015 - accuracy: 0.0000e+00
# Epoch 836/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1957 - accuracy: 0.0000e+00
# Epoch 837/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1990 - accuracy: 0.0000e+00
# Epoch 838/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2018 - accuracy: 0.0000e+00
# Epoch 839/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2030 - accuracy: 0.0000e+00
# Epoch 840/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2058 - accuracy: 0.0000e+00
# Epoch 841/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1971 - accuracy: 0.0000e+00
# Epoch 842/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1986 - accuracy: 0.0000e+00
# Epoch 843/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1984 - accuracy: 0.0000e+00
# Epoch 844/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1950 - accuracy: 0.0000e+00
# Epoch 845/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2019 - accuracy: 0.0000e+00
# Epoch 846/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1996 - accuracy: 0.0000e+00
# Epoch 847/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2055 - accuracy: 0.0000e+00
# Epoch 848/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1997 - accuracy: 0.0000e+00
# Epoch 849/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2046 - accuracy: 0.0000e+00
# Epoch 850/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2064 - accuracy: 0.0000e+00
# Epoch 851/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1996 - accuracy: 0.0000e+00
# Epoch 852/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2041 - accuracy: 0.0000e+00
# Epoch 853/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1971 - accuracy: 0.0000e+00
# Epoch 854/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1965 - accuracy: 0.0000e+00
# Epoch 855/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1963 - accuracy: 0.0000e+00
# Epoch 856/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2011 - accuracy: 0.0000e+00
# Epoch 857/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1955 - accuracy: 0.0000e+00
# Epoch 858/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1985 - accuracy: 0.0000e+00
# Epoch 859/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1963 - accuracy: 0.0000e+00
# Epoch 860/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2089 - accuracy: 0.0000e+00
# Epoch 861/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2059 - accuracy: 0.0000e+00
# Epoch 862/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1930 - accuracy: 0.0000e+00
# Epoch 863/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1952 - accuracy: 0.0000e+00
# Epoch 864/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1970 - accuracy: 0.0000e+00
# Epoch 865/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1961 - accuracy: 0.0000e+00
# Epoch 866/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1975 - accuracy: 0.0000e+00
# Epoch 867/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2009 - accuracy: 0.0000e+00
# Epoch 868/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1988 - accuracy: 0.0000e+00
# Epoch 869/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1950 - accuracy: 0.0000e+00
# Epoch 870/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1957 - accuracy: 0.0000e+00
# Epoch 871/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2036 - accuracy: 0.0000e+00
# Epoch 872/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1978 - accuracy: 0.0000e+00
# Epoch 873/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1968 - accuracy: 0.0000e+00
# Epoch 874/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1995 - accuracy: 0.0000e+00
# Epoch 875/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1980 - accuracy: 0.0000e+00
# Epoch 876/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1963 - accuracy: 0.0000e+00
# Epoch 877/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2033 - accuracy: 0.0000e+00
# Epoch 878/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2304 - accuracy: 0.0000e+00
# Epoch 879/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1981 - accuracy: 0.0000e+00
# Epoch 880/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1983 - accuracy: 0.0000e+00
# Epoch 881/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2125 - accuracy: 0.0000e+00
# Epoch 882/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2031 - accuracy: 0.0000e+00
# Epoch 883/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1947 - accuracy: 0.0000e+00
# Epoch 884/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1976 - accuracy: 0.0000e+00
# Epoch 885/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1940 - accuracy: 0.0000e+00
# Epoch 886/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1972 - accuracy: 0.0000e+00
# Epoch 887/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1944 - accuracy: 0.0000e+00
# Epoch 888/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1974 - accuracy: 0.0000e+00
# Epoch 889/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1960 - accuracy: 0.0000e+00
# Epoch 890/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1996 - accuracy: 0.0000e+00
# Epoch 891/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1946 - accuracy: 0.0000e+00
# Epoch 892/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1973 - accuracy: 0.0000e+00
# Epoch 893/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1951 - accuracy: 0.0000e+00
# Epoch 894/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1942 - accuracy: 0.0000e+00
# Epoch 895/1000
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2068 - accuracy: 0.0000e+00
# Epoch 896/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1984 - accuracy: 0.0000e+00
# Epoch 897/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1942 - accuracy: 0.0000e+00
# Epoch 898/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1963 - accuracy: 0.0000e+00
# Epoch 899/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1960 - accuracy: 0.0000e+00
# Epoch 900/1000
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2058 - accuracy: 0.0000e+00
# Epoch 901/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1947 - accuracy: 0.0000e+00
# Epoch 902/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1974 - accuracy: 0.0000e+00
# Epoch 903/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2085 - accuracy: 0.0000e+00
# Epoch 904/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2007 - accuracy: 0.0000e+00
# Epoch 905/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2021 - accuracy: 0.0000e+00
# Epoch 906/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1976 - accuracy: 0.0000e+00
# Epoch 907/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2012 - accuracy: 0.0000e+00
# Epoch 908/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2004 - accuracy: 0.0000e+00
# Epoch 909/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1963 - accuracy: 0.0000e+00
# Epoch 910/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1965 - accuracy: 0.0000e+00
# Epoch 911/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2023 - accuracy: 0.0000e+00
# Epoch 912/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1953 - accuracy: 0.0000e+00
# Epoch 913/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1985 - accuracy: 0.0000e+00
# Epoch 914/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1975 - accuracy: 0.0000e+00
# Epoch 915/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1973 - accuracy: 0.0000e+00
# Epoch 916/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1924 - accuracy: 0.0000e+00
# Epoch 917/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1950 - accuracy: 0.0000e+00
# Epoch 918/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1975 - accuracy: 0.0000e+00
# Epoch 919/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2129 - accuracy: 0.0000e+00
# Epoch 920/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2023 - accuracy: 0.0000e+00
# Epoch 921/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1945 - accuracy: 0.0000e+00
# Epoch 922/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1960 - accuracy: 0.0000e+00
# Epoch 923/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1952 - accuracy: 0.0000e+00
# Epoch 924/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1971 - accuracy: 0.0000e+00
# Epoch 925/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2005 - accuracy: 0.0000e+00
# Epoch 926/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2011 - accuracy: 0.0000e+00
# Epoch 927/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2096 - accuracy: 0.0000e+00
# Epoch 928/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1984 - accuracy: 0.0000e+00
# Epoch 929/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1950 - accuracy: 0.0000e+00
# Epoch 930/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1940 - accuracy: 0.0000e+00
# Epoch 931/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1934 - accuracy: 0.0000e+00
# Epoch 932/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1951 - accuracy: 0.0000e+00
# Epoch 933/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1945 - accuracy: 0.0000e+00
# Epoch 934/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1922 - accuracy: 0.0000e+00
# Epoch 935/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2096 - accuracy: 0.0000e+00
# Epoch 936/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2025 - accuracy: 0.0000e+00
# Epoch 937/1000
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1934 - accuracy: 0.0000e+00
# Epoch 938/1000
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1985 - accuracy: 0.0000e+00
# Epoch 939/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1941 - accuracy: 0.0000e+00
# Epoch 940/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1973 - accuracy: 0.0000e+00
# Epoch 941/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1950 - accuracy: 0.0000e+00
# Epoch 942/1000
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1973 - accuracy: 0.0000e+00
# Epoch 943/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1991 - accuracy: 0.0000e+00
# Epoch 944/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1929 - accuracy: 0.0000e+00
# Epoch 945/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1920 - accuracy: 0.0000e+00
# Epoch 946/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1946 - accuracy: 0.0000e+00
# Epoch 947/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1929 - accuracy: 0.0000e+00
# Epoch 948/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1950 - accuracy: 0.0000e+00
# Epoch 949/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1915 - accuracy: 0.0000e+00
# Epoch 950/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1967 - accuracy: 0.0000e+00
# Epoch 951/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1966 - accuracy: 0.0000e+00
# Epoch 952/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1925 - accuracy: 0.0000e+00
# Epoch 953/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1926 - accuracy: 0.0000e+00
# Epoch 954/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1944 - accuracy: 0.0000e+00
# Epoch 955/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1986 - accuracy: 0.0000e+00
# Epoch 956/1000
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1976 - accuracy: 0.0000e+00
# Epoch 957/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1948 - accuracy: 0.0000e+00
# Epoch 958/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1944 - accuracy: 0.0000e+00
# Epoch 959/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1961 - accuracy: 0.0000e+00
# Epoch 960/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1953 - accuracy: 0.0000e+00
# Epoch 961/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1934 - accuracy: 0.0000e+00
# Epoch 962/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1952 - accuracy: 0.0000e+00
# Epoch 963/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1952 - accuracy: 0.0000e+00
# Epoch 964/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1927 - accuracy: 0.0000e+00
# Epoch 965/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1977 - accuracy: 0.0000e+00
# Epoch 966/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1959 - accuracy: 0.0000e+00
# Epoch 967/1000
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1935 - accuracy: 0.0000e+00
# Epoch 968/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1976 - accuracy: 0.0000e+00
# Epoch 969/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1920 - accuracy: 0.0000e+00
# Epoch 970/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1938 - accuracy: 0.0000e+00
# Epoch 971/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1902 - accuracy: 0.0000e+00
# Epoch 972/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1942 - accuracy: 0.0000e+00
# Epoch 973/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2081 - accuracy: 0.0000e+00
# Epoch 974/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1921 - accuracy: 0.0000e+00
# Epoch 975/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1921 - accuracy: 0.0000e+00
# Epoch 976/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2162 - accuracy: 0.0000e+00
# Epoch 977/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1924 - accuracy: 0.0000e+00
# Epoch 978/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1907 - accuracy: 0.0000e+00
# Epoch 979/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1977 - accuracy: 0.0000e+00
# Epoch 980/1000
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1958 - accuracy: 0.0000e+00
# Epoch 981/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1918 - accuracy: 0.0000e+00
# Epoch 982/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1924 - accuracy: 0.0000e+00
# Epoch 983/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1897 - accuracy: 0.0000e+00
# Epoch 984/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1917 - accuracy: 0.0000e+00
# Epoch 985/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1948 - accuracy: 0.0000e+00
# Epoch 986/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1908 - accuracy: 0.0000e+00
# Epoch 987/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1907 - accuracy: 0.0000e+00
# Epoch 988/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1931 - accuracy: 0.0000e+00
# Epoch 989/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1875 - accuracy: 0.0000e+00
# Epoch 990/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1887 - accuracy: 0.0000e+00
# Epoch 991/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1862 - accuracy: 0.0000e+00
# Epoch 992/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2005 - accuracy: 0.0000e+00
# Epoch 993/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1950 - accuracy: 0.0000e+00
# Epoch 994/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1930 - accuracy: 0.0000e+00
# Epoch 995/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1942 - accuracy: 0.0000e+00
# Epoch 996/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1884 - accuracy: 0.0000e+00
# Epoch 997/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1911 - accuracy: 0.0000e+00
# Epoch 998/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.2014 - accuracy: 0.0000e+00
# Epoch 999/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1918 - accuracy: 0.0000e+00
# Epoch 1000/1000
# 40/40 [==============================] - 0s 1ms/step - loss: 0.1940 - accuracy: 0.0000e+00

# %%
z = model.predict(x)
plt.figure(figsize=(10,8))
plt.plot(x,f(x),label="Truth")
plt.plot(x,z,label="DNN")
plt.legend()
plt.show()

# %% [markdown]
# ## Problem 3
# Try increasing the number of hidden nodes per layer until performance is satisfactory. Can the same effect be achieved by just adding more layers?

# %% [markdown]
# ## Problem 4
# Using the best setup from the previous problem, train a model using the noisy data.
